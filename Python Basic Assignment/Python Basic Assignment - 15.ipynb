# %%
hr = 60 * 60
hr
# Out:
# 3600

# %%
seconds_per_hour = hr
seconds_per_hour
# Out:
# 3600

# %%
seconds_per_hour * 24
# Out:
# 86400

# %%
seconds_per_day = seconds_per_hour * 24
seconds_per_day
# Out:
# 86400

# %%
seconds_per_day/seconds_per_hour
# Out:
# 24.0

# %%
seconds_per_day//seconds_per_hour
# Out:
# 24

# %%
def gen_primes():
    n = 2
    primes = set()
    while True:
        for p in primes:
            if n % p == 0:
                break
        else:
            primes.add(n)
            yield n
        n += 1

# %%
a = gen_primes()
# Out:
# 2

# %%
next(a)
# Out:
# 7
