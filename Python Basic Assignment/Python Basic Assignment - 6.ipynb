# %% [markdown]
# 1. What are escape characters, and how do you use them?
#
# To insert characters that are illegal in a string, use an escape character.
#
# An escape character is a backslash \ followed by the character you want to insert.
#
# An example of an illegal character is a double quote inside a string that is surrounded by double quotes.

# %% [markdown]
# 2. What do the escape characters n and t stand for?
#
# \n -> Creates a new line
# \t -> Creates a tab space

# %% [markdown]
# 3. What is the way to include backslash characters in a string?
#
# Ans : \\

# %% [markdown]
# 4. The string "Howl's Moving Castle" is a correct value.
# Why isn't the single quote character in the word Howl's not escaped a problem?
#
# Sice the character is enclosed within the double quotes, it is considered as a normal string and hence the
# quotes is not creating a problem in the string

# %% [markdown]
# 5. How do you write a string of newlines if you don't want to use the n character?
#
# We have to use multiple print statements borken at the places required.

# %% [markdown]
# 6. What are the values of the given expressions?
# 'Hello, world!'[1]
#
# 'Hello, world!'[0:5]
#
# 'Hello, world!'[:5]
#
# 'Hello, world!'[3:]
#
# Ans:
#
# 'e'
#
# 'Hello'
#
# 'Hello'
#
# 'lo, world!'

# %% [markdown]
# 7. What are the values of the following expressions?
# 'Hello'.upper()
#
# 'Hello'.upper().isupper()
#
# 'Hello'.upper().lower()
#
# Ans:
#
# 'HELLO'
#
# True
#
# False

# %% [markdown]
# 8. What are the values of the following expressions?
# 'Remember, remember, the fifth of July.'.split()
# '-'.join('There can only one.'.split())
#
# Ans:
#
# ['Remember,', 'remember,', 'the', 'fifth', 'of', 'July.']
#
# 'There-can-only-one.'

# %% [markdown]
# 9. What are the methods for right-justifying, left-justifying, and centering a string?
#
# Ans:
#
# txt = "banana"
#
# x = txt.rjust(20)
#
# print(x, "is my favorite fruit.")
#
# ==================================================================
#
# txt = "banana"
#
# x = txt.ljust(20)
#
# print(x, "is my favorite fruit.")
#
# ================================================================
#
# txt = "banana"
#
# x = txt.center(20)
#
# print(x, "is my favorite fruit.")

# %% [markdown]
# 10. What is the best way to remove whitespace characters from the start or end?
#
# Ans:
#
# str1 = "    Welcome to Guru99!    "
# after_strip = str1.strip(" ")
# print(after_strip)
