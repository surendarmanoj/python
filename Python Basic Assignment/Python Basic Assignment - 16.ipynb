# %%
year = int(input("Enter the year of birth"))
years_list = []
for i in range(year, year+6):
        years_list.append(i)
print(years_list)
# Out:
# Enter the year of birth1991
# [1991, 1992, 1993, 1994, 1995, 1996]

# %%
years_list[3]
# Out:
# 1994

# %%
years_list[5]
# Out:
# 1996

# %%
lst = ["mozzarella", "cinderella", "salmonella"]

# %%
lst[1] = lst[1].upper()
lst
# Out:
# ['mozzarella', 'CINDERELLA', 'salmonella']

# %%
surprise_list = ["Groucho","Chico","Harpo"]

# %%
surprise_list[2] = surprise_list[2].lower()
surprise_list[2] = surprise_list[2][::-1].upper()
surprise_list
# Out:
# ['Groucho', 'Chico', 'OPRAH']

# %%
e2f = {'dog': 'chien', 'cat': 'chat', 'walrus': 'morse'}

# %%
e2f.get("walrus")
# Out:
# 'morse'

# %%
f2e = {}
for english, french in e2f.items():
    f2e[french] = english

# %%
f2e
# Out:
# {'chien': 'dog', 'chat': 'cat', 'morse': 'walrus'}

# %%
f2e.get("chien")
# Out:
# 'dog'

# %%
set(e2f.keys())
# Out:
# {'cat', 'dog', 'walrus'}

# %%
life = { 'animals' : { 'cats' : [ 'Henri', 'Grumpy', 'Lucy' ], 
                      'octopi' : {}, 'emus' : {}  }, 'plants' : {}, 'other' : {} }

# %%
list(life.keys())
# Out:
# ['animals', 'plants', 'other']

# %%
 set(life['animals'].keys())
# Out:
# {'cats', 'emus', 'octopi'}

# %%
 set(life['animals']['cats'])
# Out:
# {'Grumpy', 'Henri', 'Lucy'}
