# %% [markdown]
# 1. How do you distinguish between shutil.copy() and shutil.copytree()?
#
# While shutil.copy() will copy a single file,
# shutil.copytree() will copy an entire folder and every folder and file contained in it.

# %% [markdown]
# 2. What function is used to rename files?
#
# os. rename() method in Python is used to rename a file or directory.

# %% [markdown]
# 3. What is the difference between the delete functions in the send2trash and shutil modules?
#
# The send2trash functions will move a file or folder to the recycle bin,
# while shutil functions will permanently delete files and folders.

# %% [markdown]
# 4.ZipFile objects have a close() method just like File objects’ close() method.
# What ZipFile method is equivalent to File objects’ open() method?
#
# ZipFile("File_name","r") opens the file without extraxting it

# %% [markdown]
# 5. Create a programme that searches a folder tree for files with a certain file extension (such as .pdf or .jpg).
# Copy these files from whatever location they are in to a new folder.

# %%
import os
import shuthil
target = C://Desktop/New Folder

import os
for file in os.listdir("/mydir"):
    if file.endswith(".txt"):
        file_match = os.path.join("/mydir", file)
        shutil.copyfile(file_match, target)
