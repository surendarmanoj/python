# %% [markdown]
# 1. In what modes should the PdfFileReader() and PdfFileWriter() File objects will be opened?
#
# PdfFileReader() needs to be opened in read-binary mode by passing 'rb' as the second argument to open().
# Likewise, the File object passed to PyPDF2.
# PdfFileWriter() needs to be opened in write-binary mode with 'wb'.

# %% [markdown]
# 2. From a PdfFileReader object, how do you get a Page object for page 5?
#
# To extract text from a page, you need to get a Page object,
# which represents a single page of a PDF, from a PdfFileReader object.
# You can get a Page object by calling the getPage() method
# on a PdfFileReader object and passing it the page number of the page we're interested in.

# %% [markdown]
# 3. What PdfFileReader variable stores the number of pages in the PDF document?
#
# The total number of pages in the document is stored in the numPages attribute of a PdfFileReader object

# %% [markdown]
# 4. If a PdfFileReader object’s PDF is encrypted with the password swordfish,
# what must you do before you can obtain Page objects from it?
#
# PdfFileReader.decrypt('swordfish')

# %% [markdown]
# 5. What methods do you use to rotate a page?
#
# We can rotate a page clockwise or counter-clockwise by an angle.
# The PdfFileWriter is used to write the PDF file from the source PDF.
# We are using rotateClockwise(90) method to rotate the page clockwise by 90-degrees.
# We are adding the rotated pages to the PdfFileWriter instance.

# %% [markdown]
# 6. What is the difference between a Run object and a Paragraph object?
#
# A run is the object most closely associated with inline content;
# for example, if we want a set of characters to be bold in a line, we donot specify bold for every character.
# We group them and define at start and end of the group. This constitutes to Run Object
#
# A paragraph object is a list of one or more run objects in the document.
# A new paragraph starts when the user presses enter or return key and continues with the document.

# %% [markdown]
# 7. How do you obtain a list of Paragraph objects for a Document object that’s stored in a variable named doc?
#
#  The Document object contains a list of Paragraph objects for the paragraphs in the document.
#
#     "doc.paragraphs"

# %% [markdown]
# 8. What type of object has bold, underline, italic, strike, and outline variables?
#
# Run objects have the atributes of bold, underline, italic, strike and outline for a variable

# %% [markdown]
# 9. What is the difference between False, True, and None for the bold variable?
#
# True means the property is “on”, False means it is “off”. Conceptually, the None value means “inherit”.
# A run exists in the style inheritance hierarchy
# and by default inherits its character formatting from that hierarchy.

# %% [markdown]
# 10. How do you create a Document object for a new Word document?
#
# python-docx allows us to create new documents as well as make changes to existing ones.
#
# from docx import Document
#
# document = Document()
#
# document.save('test.docx')

# %% [markdown]
# 11. How do you add a paragraph with the text 'Hello, there!' to a Document object stored in a variable named doc?
#
# doc.add_paragraph('Hello, there!') command will add the paragraph to the document

# %% [markdown]
# 12. What integers represent the levels of headings available in Word documents?
#
# The arguments to add_heading() are a string of the heading text and an integer from 0 to 4.
# The integer 0 makes the heading the Title style, which is used for the top of the document.
# Integers 1 to 4 are for various heading levels, with 1 being the main heading and 4 the lowest subheading.
# The add_heading() function returns a Paragraph object to save you the step of extracting
# it from the Document object as a separate step.
