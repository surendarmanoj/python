# %% [markdown]
# 1. Is the Python Standard Library included with PyInputPlus?
#
# No. PyInputPlus is not a part of Python Standard Library

# %% [markdown]
# 2. Why is PyInputPlus commonly imported with import pyinputplus as pypi?
#
# 'as' statement is used for aliasing. This reduces the length of the package name used in the program
# by assigning a shorter and easier name for developers.

# %% [markdown]
# 3. How do you distinguish between inputInt() and inputFloat()?
#
# inputInt() - Accepts an integer number. Also has min/max/greaterThan/lessThan parameters. Returns an int, not a str.
#
# inputFloat() - Accepts a floating-point number. Also has min/max/greaterThan/lessThan parameters. Returns a float, not a str.

# %% [markdown]
# 4. Using PyInputPlus, how do you ensure that the user enters a whole number between 0 and 99?
#
# inputInt() - Accepts an integer number. Using min and max parameters,
# we can limit the value entered as input between 0 to 99

# %% [markdown]
# 5. What is transferred to the keyword arguments allowRegexes and blockRegexes?
#
# The allowRegexes and blockRegexes keyword arguments take a list of regular expression strings to determine what the
# PyInputPlus function will accept or reject as valid input.

# %% [markdown]
# 6. If a blank input is entered three times, what does inputStr(limit=3) do?
#
# This situation raises a RetryLimitException after 3 tries of wrong input.

# %% [markdown]
# 7. If blank input is entered three times, what does inputStr(limit=3, default='hello') do?
#
# This returns the default value 'hello' after 3 tries of wrong input.
