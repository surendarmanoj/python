# %% [markdown]
# 1. What exactly is []?
#
# This is a representation of an empty list.
# A list is one of the most versatile data types that allow us to work with multiple elements at once
# In Python, a list is created by placing elements inside square brackets [], separated by commas.
# A list can have any number of items and they may be of different types (integer, float, string, etc.).

# %% [markdown]
# 2. In a list of values stored in a variable called spam,
# how would you assign the value 'hello' as the third value?
# (Assume [2, 4, 6, 8, 10] are in spam.)

# %%
spam[2] = "hello"

# %% [markdown]
# 3. What is the value of spam[int(int('3' * 2) / 11)]?
#
# Ans : 'd'

# %% [markdown]
# 4. What is the value of spam[-1]?
#
# Ans : 'd'

# %% [markdown]
# 5. What is the value of spam[:2]?
#
# Ans : ['a','b']

# %% [markdown]
# 6. What is the value of bacon.index('cat')?
# Ans : 1

# %% [markdown]
# 7. How does bacon.append(99) change the look of the list value in bacon?
#
# Ans: The value gets added to the last of the list
#     [3.14, 'cat', 11, 'cat', True, 99]

# %% [markdown]
# 8. How does bacon.remove('cat') change the look of the list in bacon?
#
# Ans : It removes the first occourance of the element
#     [3.14, 11, 'cat', True]

# %% [markdown]
# 9. What are the list concatenation and list replication operators?
#
# List concatination -> +,+=
# List replication -> *, *=

# %% [markdown]
# 10. What is difference between the list methods append() and insert()?
#
# The difference between append() and insert() is that insert function allows us to add a specific element at a
# specified index of the list unlike append() where we can add the element only at end of the list.

# %% [markdown]
# 11. What are the two methods for removing items from a list?
#
# Ans : Remove , Pop

# %% [markdown]
# 12. Describe how list values and string values are identical.
#
# Strings and lists share many similarities.
# However, strings are not interchangeable with lists because of some important differences.
#
# Strings can only consist of characters, while lists can contain any data type.
#
# Because of the previous difference, we cannot easily make a list into a string,
# but we can make a string into a list of characters, simply by using the list() function.

# %% [markdown]
# 13. What's the difference between tuples and lists?
#
# The key difference between the tuples and lists is that while the tuples are immutable objects the lists are mutable.
# This means that tuples cannot be changed while the lists can be modified.
#
# As lists are mutable, Python needs to allocate an extra memory
# block in case there is a need to extend the size of the list object after it is created. In contrary,
# as tuples are immutable and fixed size, Python allocates just the minimum memory block required for the data.
#
# The key difference between the tuples and lists is that while the tuples are immutable objects the lists are mutable.
# This means that tuples cannot be changed while the lists can be modified.
#
# Tuples are more memory efficient than the lists.
#
# When it comes to the time efficiency, again tuples have a slight advantage over the lists especially
# when lookup to a value is considered.
#
# If you have data which is not meant to be changed in the first place, you should choose tuple data type over lists.

# %% [markdown]
# 14. How do you type a tuple value that only contains the integer 42?
#
# Ans: int

# %% [markdown]
# 15. How do you get a list value's tuple form? How do you get a tuple value's list form?
#
# We can typecase the list to tuple by using tuple(list_name) and tuple to list(tuple_name)

# %% [markdown]
# 16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?
#
# Ans: They have address of the first element of the list pointed in the variable

# %% [markdown]
# 17. How do you distinguish between copy.copy() and copy.deepcopy()?
#
# The difference between shallow and deep copying is only relevant for compound objects
# (objects that contain other objects, like lists or class instances):
#
# A shallow copy constructs a new compound object and then (to the extent possible)
# inserts references into it to the objects found in the original.
#
# A deep copy constructs a new compound object and then, recursively, inserts copies into it of the objects found
# in the original.
