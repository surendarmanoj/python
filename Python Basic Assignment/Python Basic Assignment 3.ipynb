# %% [markdown]
# 1. Why are functions advantageous to have in your programs?
#
# Functions are reusable blocks of codes which runs only when they are called for.
# They have the capacity to get argument values run time and provide decision and output based on the input.
# While stored in centralised location, it is possible for them to be reused across the app.
# This reduces the number of lines of codes involved and makes the maintainanace of code very easy.

# %% [markdown]
# 2. When does the code in a function run: when it's specified or when it's called?
#
# The code in the function runs only when it is called for and the required parametres are passed

# %% [markdown]
# 3. What statement creates a function?
#
# Def Statement creates a function.

# %% [markdown]
# 4. What is the difference between a function and a function call?
#
# A function is a block of code that does a particular operation and returns a result.
# It usually accepts inputs as parameters and returns a result. The parameters are not mandatory.
#
# E.g:
# Function add(a,b)
# return a+ b
#
# A function call is the code used to pass control to a function.
#
# E.g.:
#
# b = add(5,6)
#
# Now b will have the value 11.

# %% [markdown]
# 5. How many global scopes are there in a Python program? How many local scopes?
#
# We can have only one glogal variable per python program.
# We can have morethan one local scopes.

# %% [markdown]
# 6. What happens to variables in a local scope when the function call returns?
#
# The local variables will be purged from the memory and the memory will be reallocated to some other variable
# once the function call is done.

# %% [markdown]
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?
#
# Retuen value is an option available in python functions which are used to transfer or store the output
# value of the function in the caller. This can be used to perform actions in the function and the output
# is used in the main program.
#
# Expression cannot have a return statement directly as it is validated and compiled by the compiler and output is
# produced then and there. These expressions can be directly associated to the variables and used in the main program

# %% [markdown]
# 8. If a function does not have a return statement, what is the return value of a call to that function?
#
# If a function has no return value in it, it's return value will be none.

# %% [markdown]
# 9. How do you make a function variable refer to the global variable?
#
# We have to use the global keyword in the function before the reference to the global variable.

# %% [markdown]
# 10. What is the data type of None?
#
# None is used to define the Null values in the data. None is of it's own datatype.

# %% [markdown]
# 11. What does the sentence import areallyourpetsnamederic do?
#
# It imports the package named areallyourpetsnamederic and allows us to use the functions defined in
# the package in our program

# %% [markdown]
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
#
# We call it Defenitions.

# %% [markdown]
# 13. What can you do to save a programme from crashing if it encounters an error?
#
# Use try/ Catch to handle the errors and handle the errors predicted based on the exceptions arising.
# This prevents the crash of the program.

# %% [markdown]
# 14. What is the purpose of the try clause? What is the purpose of the except clause?
#
# Try block allows you to test our code for errors and except block allows us to user define errors
# which handles the errors gracefully in run time.
