# %% [raw]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -87.8
# -
# /
# +
# 6

# %% [raw]
# Expressions -> *,-,/,+
# Values -> 'hello', -87.8,6

# %% [raw]
# 2. What is the difference between string and variable?

# %% [raw]
# Variable is an address to a location where we have stored a specific data in the system.
# It can be considered as a identifier for a memory location and can be manipulated when needed.
# eg: x = 10
#
# String is a value that is assigned to a variable.
# Anything that is enclosed in single or double quotes constitutes to a string in python
# eg: "Surendar Manoj"

# %% [raw]
# 3. Describe three different data types.

# %% [raw]
# Number Data Types:
#     There are three types of numbers - Complex numbers, floating datatypes and integers
#     Complex numbers have a imaginary part and a real part.
#     Floating numbers are the ones with decimal fields.It is denoted as float
#     Integers are the representation of whole numbers. It is denoted as int.
#
#     Each of these number tyrpes have their own significance based on the problem
#     in which they are used and the output expected.
#
# String Data Types:
#     String is a sequence of characters. It is denoted by str.
#     It is commonly enclosed between "" or ''.
#     All characters enclosed between the quotes are part of string including spaces and special characters.
#     There is no limitation on the number of characters in the string.
#     The only limitation will be the memory resource of the machine processing the data
#
# Boolean Data Types:
#     They can accept only two values - True or False
#     These Data types are used to make decisions while the program is getting executed.
#     They are denoted by bool.
#     They are the outcome of most of the logical operators and condition statements.
#     They are used to make the flow of the program smart.

# %% [raw]
# 4. What is an expression made up of? What do all expressions do?

# %% [raw]
# An Expression is a combination of values, variables, operators and alls to functions
# Expressions needs to be evaluated. if we ask python to do a print statement of an expression,
# the interpretor evaluates the value in backend and displays the result.
#
# There are expressions which can perform multiple different types of actions
# 1.Logical
# 2.Arithmatic
# 3.Assignment

# %% [raw]
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %% [raw]
# Expression is a set of instruction which is interpreted by the compiler to produce output.
#
# Statement is a standalone part of the program execution. it doesn't necessarily have to return anything.

# %%
bacon = 22
bacon + 1
# Out:
# 23

# %% [raw]
# bacon = 23

# %%
'spam' + 'spamspam'
'spam' * 3
# Out:
# 'spamspamspam'

# %% [raw]
# 'spamspamspam'

# %% [raw]
# 8. Why is eggs a valid variable name while 100 is invalid?

# %% [raw]
# A variable can have a short name (like x and y) or a more descriptive name (age, carname, total_volume).
#
# A variable name must start with a letter or the underscore character
# A variable name cannot start with a number
# A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
# Variable names are case-sensitive (age, Age and AGE are three different variables)

# %% [raw]
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?

# %%
x = 10
y = str(x)
z = int(x)
w = float(x)
y,z,w
# Out:
# ('10', 10, 10.0)

# %% [raw]
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'

# %%
# + operator cannot work on different data types. We have to convert 99 to string.
'I have eaten ' + '99' + ' burritos.'
# Out:
# 'I have eaten 99 burritos.'
